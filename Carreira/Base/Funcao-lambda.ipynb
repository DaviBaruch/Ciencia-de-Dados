# %%
nota = float(input("Digite a nota do aluno: "))

def qualitativo(x):
    return x + 0.5

# %%
qualitativo(nota)
# Out:
# 8.5

# %%
nota = float(input("Digite a nota do aluno: "))

lambda x: x + 0.5
    
qualitativo(nota)
# Out:
# 9.5

# %%
n1 = float(input("Digite sua nota: "))
n2 = float(input("Digite sua nota: "))
n3 = float(input("Digite sua nota: "))

media_ponderavel = lambda x, y, z: (x * 3 + y * 2 + 5 * z)/10
estudante_media = media_ponderavel(n1, n2, n3)
print(f"O aluno atingiu a média de {estudante_media}")
# Out:
# O aluno atingiu a média de 8.2

# %% [markdown]
# Exercícios

# %%
lista = [16, 14, 63, 65, 17, 99, 70, 11, 20, 48, 79, 32, 17, 89, 12, 25, 66]
qnt = len(lista)
menor = min(lista)
maior = max(lista)
print(f"A quantidade de números nessa lista é de {qnt}, o maior número dela é {maior} e o menor número dela é {menor}!")
# Out:
# A quantidade de números nessa lista é de 17, o maior número dela é 99 e o menor número dela é 11!
